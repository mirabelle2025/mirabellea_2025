# %% [markdown]
# ---
# layout: post
# title: Color Codes/Images/Base64
# description: Color Codes/Images/Base64 Notes and Homework
# courses: { csp: {week:1} }
# menu: nav/tri3lesson.html
# permalink: /tri3lesson/3-12
# comments: true
# ---

# %% [markdown]
# ## Popcorn Hacks
# 1️⃣ Which image format is best for logos and transparency? <br/>
# Answer: PNG (PNG supports transparency and preserves image quality.)<br/>
# 2️⃣ Which format loses quality to make the file size smaller?<br/>
# Answer: JPG / JPEG (JPEG uses lossy compression to shrink file size.)<br/>
# 3️⃣ Which format is used for simple animations, like memes?<br/>
# Answer: GIF (GIF supports basic animations and limited color.)<br/>

# %% [markdown]
# ## POPCORN HACK: Decode This!
# Question:<br/>
# What does this Base64 string decode to? U1Q=<br/>
#
# Answer<br/>
# U1Q= → ST<br/>
# - U = 20 → 010100<br/>
# - 1 = 53 → 110101<br/>
# - Q = 16 → 010000<br/>
# Together = 01010011 01010100 = ASCII for "ST"<br/>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <title>My Mood Board</title>
#   <style>
#     body {
#       font-family: Arial, sans-serif;
#       text-align: center;
#       padding: 20px;
#     }
#     .color-box {
#       width: 150px;
#       height: 150px;
#       display: inline-block;
#       margin: 10px;
#       border-radius: 10px;
#       line-height: 150px;
#       color: #333;
#       font-weight: bold;
#       box-shadow: 0 0 10px rgba(0,0,0,0.1);
#     }
#   </style>
# </head>
# <body>
#   <h1>🎨 My Mood Board</h1>
#   <div class="color-box" style="background-color: #FF9FB2;">#87CEEB</div>
#   <div class="color-box" style="background-color: #FBDCE2;">#FF7F50</div>
#   <div class="color-box" style="background-color: #E6E6FA;">#0ACDFF</div>
#   <div class="color-box" style="background-color: #98FF98;">#60AB9A</div>
#   <div class="color-box" style="background-color: #FFFACD;">#DEDEE0</div>
# </body>
# </html>

# %% [markdown]
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <title>My Base64 Profile Pic</title>
# </head>
# <body>
#   <h1>🎒 My Embedded Profile Picture</h1>
#   <img src="data:image/png;base64,..." alt="Profile Picture" width="200">
# </body>
# </html>
